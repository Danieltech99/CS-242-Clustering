# %%
from scipy.ndimage.measurements import center_of_mass
import numpy as np
import matplotlib.pyplot as plt

from pyclustering.cluster.cure import cure

# %%
data = np.load("Data/sklearn_data.npz")["circles_vlow_noise"]
labels = np.load("Data/sklearn_labels.npz")["circles_vlow_noise"]

# %%
# plt.scatter(data[:, 0], data[:, 1], c=labels, s=0.5)
for i in range(0, 2):
    label_mask = labels[labels == i]
    data_i = data[labels == i]
    center = np.array(np.sum(data_i, axis=0)/np.shape(data_i)[0])
    # print(center)
    print(i, labels==0)
    plt.scatter(data_i[:, 0], data_i[:, 1], s=1)
    plt.scatter(center[0], center[1])
# Out:
# 0 [False False False ...  True False  True]
# 1 [False False False ...  True False  True]

# %%
a = np.array([[0, 1, 4], [-1, -2, -3]])
b = np.array([2, 3, -1])
c = np.array([0, -2, 1])

l = [a, b, c]
l
# Out:
# [array([[ 0,  1,  4],
#         [-1, -2, -3]]), array([ 2,  3, -1]), array([ 0, -2,  1])]

# %%
np.vstack(l)
# Out:
# array([[ 0,  1,  4],
#        [-1, -2, -3],
#        [ 2,  3, -1],
#        [ 0, -2,  1]])

# %%
cure_inst = cure(data, 2, 100, compression=0.01)
cure_inst.process()

cure_labels = cure_inst.get_clusters()

# %%
rep_pts0 = np.array(cure_inst.get_representors()[0])
rep_pts1 = np.array(cure_inst.get_representors()[1])

# %%
label0 = set(cure_labels[0])

cure_label_vec = np.array([0 if x in label0 else 1 for x in range(data.shape[0])])
cure_label_vec
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
plt.scatter(data[:, 0], data[:, 1], s=1, c=cure_label_vec, cmap="bwr")

# %%
plt.scatter(rep_pts0[:, 0], rep_pts0[:, 1])
plt.scatter(rep_pts1[:, 0], rep_pts1[:, 1])

# %%
# np.vstack(cure_inst.get_representors())

# %%
np.load("data/singlecluster_multigroup_data.npz").files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-f812fc39b742> in <module>
# ----> 1 np.load("data/singlecluster_multigroup_data.npz").files
#
# ~/miniconda3/envs/datasci/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/singlecluster_multigroup_data.npz'

# %%
derp = np.array([50, 39, 30, 20, 18, 16, 15 , 14, 13.5])
plt.plot(derp)
print(np.diff(derp, n=1))
print(np.diff(derp, n=2))
print(np.argmax(np.diff(derp, n=2) > 5))
# Out:
# [-11.   -9.  -10.   -2.   -2.   -1.   -1.   -0.5]
# [ 2.  -1.   8.   0.   1.   0.   0.5]
# 2

# %%
data = np.load("Data/multigroup_data.npz")["blobs_low_noise"]

plt.scatter(data[:, 0], data[:, 1], s=1)

# %%
import importlib
try:
    importlib.reload(k_means)
except: 
    pass
from Algorithms import k_means


k_means.find_optimal_k2(data, 2, 10)
# Out:
# sum of squares:
# [35067.6058048  21809.54217586 13350.21122182  9048.72939831
#   4966.02925332  1773.13273232  1672.70829169  1571.76011785
#   1474.16357702  1381.33534715]
#
# sum of squares delta:
# [-13258.06362894  -8459.33095404  -4301.48182351  -4082.70014499
#   -3192.89652099   -100.42444063   -100.94817384    -97.59654083
#     -92.82822988]
# sum of squares delta delta
# [-4.27868621e-05 -1.14265363e-04 -1.24579146e-05 -6.82592966e-05
#  -9.64421099e-03  5.16570242e-05 -3.40157046e-04 -5.26262108e-04]
# ss delta_threshold
# 2
# 2

# %%
import importlib
try:
    importlib.reload(k_means)
except: 
    pass
from Algorithms import k_means

import time

start_time = time.time()
k_means.find_optimal_k_silhouette(data, 10)
print("total time:", time.time() - start_time)
# Out:
# total time: 19.270808458328247

# %%
1/np.diff([0, 3, 4, 5, 7])
# Out:
# array([0.33333333, 1.        , 1.        , 0.5       ])

# %%
# data = np.load("Data/multigroup_data.npz")["circle_vhigh_noise"]
data = np.load("Data/sklearn_data.npz")["moons_vlow_noise"]

plt.scatter(data[:, 0], data[:, 1], s=1)

# %%
import importlib
try:
    importlib.reload(k_means)
except: 
    pass
from Algorithms import k_means

import time

start_time = time.time()
k_means.find_optimal_k_atan(data, 2, 10)
print("total time:", time.time() - start_time)
# Out:
# [6.01018619 1.31750979 0.94335275 0.43319486 0.4197218  0.18103722
#  0.18612939 0.09267937 0.0878187 ]
# total time: 3.4604008197784424

# %%
np.array([np.nan, 1, 4])
# Out:
# array([nan,  1.,  4.])

# %%
np.zeros(5)
# Out:
# array([0., 0., 0., 0., 0.])

# %%
data = np.load("Data/multigroup_data.npz")["blobs_vhigh_noise"]
# data = np.load("Data/sklearn_data.npz")["moons_vlow_noise"]

plt.scatter(data[:, 0], data[:, 1], s=1)

# %%
centers = np.array([[3, 3], [-3, -3], [0, 0], [np.nan, np.nan]])
print(centers)

plt.scatter(data[:, 0], data[:, 1], s=1)
plt.scatter(centers[:, 0], centers[:, 1])
# Out:
# [[ 3.  3.]
#  [-3. -3.]
#  [ 0.  0.]
#  [nan nan]]

# %%
from sklearn.metrics import pairwise_distances, pairwise_distances_argmin, pairwise_distances_argmin_min

labels, distances = pairwise_distances(data, centers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-90-2019672887cb> in <module>
#       1 from sklearn.metrics import pairwise_distances, pairwise_distances_argmin, pairwise_distances_argmin_min
#       2
# ----> 3 labels, distances = pairwise_distances(data, centers)
#
# ~/miniconda3/envs/datasci/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, **kwds)
#    1586         func = partial(distance.cdist, metric=metric, **kwds)
#    1587
# -> 1588     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1589
#    1590
#
# ~/miniconda3/envs/datasci/lib/python3.7/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1204
#    1205     if effective_n_jobs(n_jobs) == 1:
# -> 1206         return func(X, Y, **kwds)
#    1207
# ...

# %%
a = np.zeros((4, 2))
a[2] = 19
a
# Out:
# array([[ 0.,  0.],
#        [ 0.,  0.],
#        [19., 19.],
#        [ 0.,  0.]])
